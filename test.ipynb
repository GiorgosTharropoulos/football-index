# %%
import pandas as pd
import numpy as np
POS_DICT = {
    'Goalkeeper': ['GK'],
    'Full Back': ['LB', 'LB5', 'RB', 'RB5'],
    'Wing Back': ['LWB', 'RWB'],
    'Center Back': ['CB', 'CB3', 'RCB', 'LCB', 'RCB3', 'LCB3'],
    'Defensive Midfielder': ['DMF', 'RDMF', 'LDMF'],
    'Central Midfielder': ['LCMF', 'LCMF3', 'RCMF', 'RCMF3'],
    'Attacking Midfielder': ['AMF', 'LAMF', 'RAMF'],
    'Winger': ['LW', 'RW'],
    'Wing Forward': ['LWF', 'RWF'],
    'Striker': ['CF']
}

# %%
file_path = 'C:/Users/githk/Projects/footballindex/Sample Data/raw stats/GRE1.xlsx'

gr_df = pd.read_excel(file_path)

# %%
gr_df.columns = [col.lower() for col in gr_df.columns]
# Out:
# Index(['player', 'team', 'team within selected timeframe', 'position', 'age',
#        'market value', 'contract expires', 'matches played', 'minutes played',
#        'goals',
#        ...
#        'prevented goals per 90', 'back passes received as gk per 90',
#        'exits per 90', 'aerial duels per 90.1', 'free kicks per 90',
#        'direct free kicks per 90', 'direct free kicks on target, %',
#        'corners per 90', 'penalties taken', 'penalty conversion, %'],
#       dtype='object', length=115)

# %%
gr_df.iloc[]

# %%
keywords = ['won', 'accurate', 'successful']
percentage_cols = [col for col in gr_df.columns if '%' in col]
for col in percentage_cols:
    for keyword in keywords:
        if keyword in col:
            col_name = col.replace(', %', '') + ' per 90'
            gr_df[col.replace(keyword, '').replace(', %', '').strip() + ' per 90'] * gr_df[col]
            print(gr_df[col.replace(keyword, '').replace(', %', '').strip() + ' per 90'])

gr_df.iloc[433]['forward passes per 90']
# Out:
# 0      19.66
# 1      23.65
# 2      16.34
# 3      25.11
# 4       0.93
#        ...
# 429     9.43
# 430    16.89
# 431      NaN
# 432    20.30
# 433    15.58
# Name: duels per 90, Length: 434, dtype: float64
# 0      6.21
# 1      5.01
# 2      5.96
# 3      4.19
# 4      0.08
#        ...
# 429    6.00
# 430    6.72
# 431     NaN
# 432    5.74
# 433    6.92
# Name: defensive duels per 90, Length: 434, dtype: float64
# 0      2.40
# 1      3.27
# 2      4.56
# 3      2.53
# 4      0.53
#        ...
# 429    2.57
# 430    4.89
# 431     NaN
# 432    3.78
# 433    1.73
# Name: aerial duels per 90, Length: 434, dtype: float64
# 0      1.60
# 1      3.06
# 2      0.00
# 3      3.45
# 4      0.00
#        ...
# 429    0.00
# 430    0.29
# 431     NaN
# 432    0.14
# 433    0.00
# Name: crosses per 90, Length: 434, dtype: float64
# 0      0.52
# 1      2.81
# 2      0.00
# 3      1.17
# 4      0.00
#        ...
# 429    0.00
# 430    0.29
# 431     NaN
# 432    0.00
# 433    0.00
# Name: crosses from left flank per 90, Length: 434, dtype: float64
# 0      1.08
# 1      0.26
# 2      0.00
# 3      2.28
# 4      0.00
#        ...
# 429    0.00
# 430    0.00
# 431     NaN
# 432    0.14
# 433    0.00
# Name: crosses from right flank per 90, Length: 434, dtype: float64
# 0      2.87
# 1      5.21
# 2      0.99
# 3      6.35
# 4      0.04
#        ...
# 429    0.00
# 430    1.54
# 431     NaN
# 432    2.24
# 433    2.60
# Name: dribbles per 90, Length: 434, dtype: float64
# 0       7.48
# 1      11.39
# 2       2.57
# 3      14.00
# 4       0.24
#        ...
# 429     0.86
# 430     2.59
# 431      NaN
# 432     6.86
# 433     5.19
# Name: offensive duels per 90, Length: 434, dtype: float64
# 0      58.68
# 1      30.80
# 2      60.48
# 3      55.33
# 4      17.66
#        ...
# 429    60.00
# 430    28.59
# 431      NaN
# 432    61.59
# 433    38.94
# Name: passes per 90, Length: 434, dtype: float64
# 0      18.76
# 1       5.52
# 2      22.12
# 3      12.52
# 4       9.64
#        ...
# 429    19.71
# 430    16.50
# 431      NaN
# 432    18.34
# 433     5.19
# Name: forward passes per 90, Length: 434, dtype: float64
# 0       8.18
# 1       7.25
# 2       3.39
# 3      12.09
# 4       0.00
#        ...
# 429     5.14
# 430     2.59
# 431      NaN
# 432    10.64
# 433     7.79
# Name: back passes per 90, Length: 434, dtype: float64
# 0      22.10
# 1      10.42
# 2      30.33
# 3      19.80
# 4       7.29
#        ...
# 429    32.57
# 430     7.00
# 431      NaN
# 432    20.86
# 433    13.85
# Name: lateral passes per 90, Length: 434, dtype: float64
# 0      52.10
# 1      26.56
# 2      55.70
# 3      46.70
# 4      12.23
#        ...
# 429    57.43
# 430    22.07
# 431      NaN
# 432    59.91
# 433    36.35
# Name: short / medium passes per 90, Length: 434, dtype: float64
# 0      5.03
# 1      1.43
# 2      4.78
# 3      5.18
# 4      5.39
#        ...
# 429    2.57
# 430    6.24
# 431     NaN
# 432    1.54
# 433    2.60
# Name: long passes per 90, Length: 434, dtype: float64
# 0      1.18
# 1      1.17
# 2      0.14
# 3      1.11
# 4      0.00
#        ...
# 429    0.00
# 430    0.10
# 431     NaN
# 432    0.42
# 433    0.87
# Name: smart passes per 90, Length: 434, dtype: float64
# 0      9.55
# 1      2.76
# 2      6.50
# 3      6.35
# 4      0.81
#        ...
# 429    4.29
# 430    4.99
# 431     NaN
# 432    8.12
# 433    6.06
# Name: passes to final third per 90, Length: 434, dtype: float64
# 0      2.82
# 1      3.37
# 2      0.41
# 3      4.32
# 4      0.00
#        ...
# 429    0.86
# 430    0.48
# 431     NaN
# 432    1.68
# 433    0.87
# Name: passes to penalty area per 90, Length: 434, dtype: float64
# 0      1.79
# 1      0.77
# 2      0.45
# 3      1.11
# 4      0.00
#        ...
# 429    1.71
# 430    0.29
# 431     NaN
# 432    0.70
# 433    0.87
# Name: through passes per 90, Length: 434, dtype: float64
# 0      8.61
# 1      4.70
# 2      9.16
# 3      5.92
# 4      4.50
#        ...
# 429    4.29
# 430    7.39
# 431     NaN
# 432    6.58
# 433    8.65
# Name: progressive passes per 90, Length: 434, dtype: float64
# 5.19
